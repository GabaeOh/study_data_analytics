# %% [markdown]
# ## quest 1
# - 주차별 환자 입원/퇴원 추이 시각화
# - 요일별 환자 입원/퇴원 추이 시각화

# %% [markdown]
# ### 분석 결론
# - 주자별 입/퇴원
#     - 2019년~2020년도에 환자 입/퇴원 비율이 눈에띄게 많아짐을 알수 있음
#     - 입원 비율을 매년 중반에 많은 비중을 차지하고 있음
#     - 퇴원 비율은 매년 하반기에 많은 비중을 차지하고 있음을 확인함.
# - 요일별 입/퇴원
#     - 입원 비율은 주말보다는 평일에 눈에 띄게 많음을 알수 있으며, 특히 목요일이 가장 많은 비중을 차지함
#     - 퇴원 비율을 일요일, 월요일이 비중이 현저히 적음을 알수 있으며, 나머지 요일을 골고루 분포되었음을 확임함.

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('font',family='Malgun Gothic')
import seaborn as sns
import pandas as pd
import scipy.stats as stats

# %%
df_ROS = pd.read_csv('../../datasets/RecurrenceOfSurgery.csv')
df_ROS.head(2)
# Out:
#    Unnamed: 0 환자ID  Large Lymphocyte  Location of herniation   ODI  가족력  \
# 0           0  1PT              22.8                       3  51.0  0.0
# 1           1  2PT              44.9                       4  26.0  0.0
#
#    간질성폐질환  고혈압여부  과거수술횟수  당뇨여부  ...  Modic change    PI    PT  Seg Angle(raw)  \
# 0       0      0       0     0  ...             3  51.6  36.6            14.4
# 1       0      0       0     0  ...             0  40.8   7.2            17.8
#
#    Vaccum disc   골밀도  디스크단면적  디스크위치  척추이동척도  척추전방위증
# 0            0 -1.01  2048.5      4    Down       0
# 1            0 -1.14  1753.1      4      Up       0
#
# [2 rows x 52 columns]

# %%
df_ROS.columns
# Out:
# Index(['Unnamed: 0', '환자ID', 'Large Lymphocyte', 'Location of herniation',
#        'ODI', '가족력', '간질성폐질환', '고혈압여부', '과거수술횟수', '당뇨여부', '말초동맥질환여부', '빈혈여부',
#        '성별', '스테로이드치료', '신부전여부', '신장', '심혈관질환', '암발병여부', '연령', '우울증여부', '입원기간',
#        '입원일자', '종양진행여부', '직업', '체중', '퇴원일자', '헤모글로빈수치', '혈전합병증여부', '환자통증정도',
#        '흡연여부', '통증기간(월)', '수술기법', '수술시간', '수술실패여부', '수술일자', '재발여부', '혈액형',
#        '전방디스크높이(mm)', '후방디스크높이(mm)', '지방축적도', 'Instability', 'MF + ES',
#        'Modic change', 'PI', 'PT', 'Seg Angle(raw)', 'Vaccum disc', '골밀도',
#        '디스크단면적', '디스크위치', '척추이동척도', '척추전방위증'],
#       dtype='object')

# %%
df_ROS[['입원일자','퇴원일자']] = df_ROS[['입원일자','퇴원일자']].astype(str)

# %%
df_ROS['입원일자_datetime']= pd.to_datetime(df_ROS['입원일자'])
df_ROS['입원일자_datetime']
# Out:
# 0      2019-07-13
# 1      2019-07-15
# 2      2019-07-29
# 3      2019-07-31
# 4      2019-09-03
#           ...
# 1889   2017-04-07
# 1890   2017-04-26
# 1891   2017-04-10
# 1892   2017-04-08
# 1893   2017-04-12
# Name: 입원일자_datetime, Length: 1894, dtype: datetime64[ns]

# %%
df_ROS['퇴원일자_datetime']= pd.to_datetime(df_ROS['퇴원일자'])
df_ROS['퇴원일자_datetime']
# Out:
# 0      2019-07-16
# 1      2019-07-16
# 2      2019-08-01
# 3      2019-08-03
# 4      2019-09-07
#           ...
# 1889   2017-04-08
# 1890   2017-04-29
# 1891   2017-04-12
# 1892   2017-04-11
# 1893   2017-04-13
# Name: 퇴원일자_datetime, Length: 1894, dtype: datetime64[ns]

# %%
df_ROS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1894 entries, 0 to 1893
# Data columns (total 59 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1894 non-null   int64
#  1   환자ID                    1894 non-null   object
#  2   Large Lymphocyte        1894 non-null   float64
#  3   Location of herniation  1894 non-null   int64
#  4   ODI                     462 non-null    float64
#  5   가족력                     1843 non-null   float64
#  6   간질성폐질환                  1894 non-null   int64
#  7   고혈압여부                   1894 non-null   int64
#  8   과거수술횟수                  1894 non-null   int64
#  9   당뇨여부                    1894 non-null   int64
#  10  말초동맥질환여부                1894 non-null   int64
#  11  빈혈여부                    1894 non-null   int64
#  12  성별                      1894 non-null   int64
#  13  스테로이드치료                 1894 non-null   int64
#  14  신부전여부                   1894 non-null   int64
#  15  신장                      1894 non-null   int64
#  16  심혈관질환                   1894 non-null   int64
#  17  암발병여부                   1894 non-null   int64
#  18  연령                      1894 non-null   int64
#  19  우울증여부                   1894 non-null   int64
#  20  입원기간                    1894 non-null   int64
#  21  입원일자                    1894 non-null   object
#  22  종양진행여부                  1894 non-null   int64
#  23  직업                      1479 non-null   object
#  24  체중                      1894 non-null   float64
#  25  퇴원일자                    1894 non-null   object
#  26  헤모글로빈수치                 1893 non-null   float64
#  27  혈전합병증여부                 1894 non-null   int64
#  28  환자통증정도                  1894 non-null   int64
#  29  흡연여부                    1894 non-null   int64
#  30  통증기간(월)                 1890 non-null   float64
#  31  수술기법                    1813 non-null   object
#  32  수술시간                    1840 non-null   float64
#  33  수술실패여부                  1894 non-null   int64
#  34  수술일자                    1894 non-null   int64
#  35  재발여부                    1894 non-null   int64
#  36  혈액형                     1894 non-null   object
#  37  전방디스크높이(mm)             1894 non-null   float64
#  38  후방디스크높이(mm)             1894 non-null   float64
#  39  지방축적도                   1891 non-null   float64
#  40  Instability             1894 non-null   int64
#  41  MF + ES                 1894 non-null   float64
#  42  Modic change            1894 non-null   int64
#  43  PI                      1890 non-null   float64
#  44  PT                      1890 non-null   float64
#  45  Seg Angle(raw)          1893 non-null   float64
#  46  Vaccum disc             1894 non-null   int64
#  47  골밀도                     998 non-null    float64
#  48  디스크단면적                  1893 non-null   float64
#  49  디스크위치                   1894 non-null   int64
#  50  척추이동척도                  1894 non-null   object
#  51  척추전방위증                  1894 non-null   int64
#  52  입원일자_datetime           1894 non-null   datetime64[ns]
#  53  퇴원일자_datetime           1894 non-null   datetime64[ns]
#  54  입원일자_datetime_week      1894 non-null   int64
#  55  퇴원일자_datetime_week      1894 non-null   int64
#  56  입원일자_datetime_day       1894 non-null   object
#  57  퇴원일자_datetime_day       1894 non-null   object
#  58  환자ID_count              0 non-null      float64
# dtypes: datetime64[ns](2), float64(17), int64(31), object(9)
# memory usage: 873.1+ KB

# %% [markdown]
# #### 주차별 환자 입/퇴원 추이 시각화

# %%
df_ROS['입원일자_datetime_week']= df_ROS['입원일자_datetime'].dt.week
# Out:
# C:\Users\02-19\AppData\Local\Temp\ipykernel_4532\240339961.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df_ROS['입원일자_datetime_week']= df_ROS['입원일자_datetime'].dt.week

# %%
df_ROS['퇴원일자_datetime_week']= df_ROS['퇴원일자_datetime'].dt.week
# Out:
# C:\Users\02-19\AppData\Local\Temp\ipykernel_4532\1330745939.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df_ROS['퇴원일자_datetime_week']= df_ROS['퇴원일자_datetime'].dt.week

# %%
pd.pivot_table(data=df_ROS, index=['입원일자_datetime'], values='입원일자_datetime_week', aggfunc=sum)
# Out:
#                입원일자_datetime_week
# 입원일자_datetime
# 2009-01-20                      4
# 2009-01-30                      5
# 2009-03-10                     11
# 2009-03-27                     13
# 2009-03-31                     28
# ...                           ...
# 2020-07-28                     62
# 2020-07-29                     93
# 2020-07-30                     62
# 2020-08-03                     32
# 2020-08-04                     32
#
# [1051 rows x 1 columns]

# %%
pd.pivot_table(data=df_ROS, index=['퇴원일자_datetime'], values='퇴원일자_datetime_week', aggfunc=sum)
# Out:
#                퇴원일자_datetime_week
# 퇴원일자_datetime
# 2009-01-24                      4
# 2009-03-12                     11
# 2009-03-28                     13
# 2009-04-01                     14
# 2009-04-02                     14
# ...                           ...
# 2020-07-30                    124
# 2020-07-31                     31
# 2020-08-01                    124
# 2020-08-04                     32
# 2020-08-07                     32
#
# [1012 rows x 1 columns]

# %% [markdown]
# ##### 주차별 퇴원일자 시각화

# %%
sns.lineplot(data=df_ROS,  x='퇴원일자_datetime', y='퇴원일자_datetime_week', estimator=sum)
plt.show()

# %% [markdown]
# ##### 주차별 입원일자 시각화

# %%
sns.lineplot(data=df_ROS,  x='입원일자_datetime', y='입원일자_datetime_week', estimator=sum)
plt.show()

# %% [markdown]
# #### 요일별 환자 입/퇴원 추이 시각화

# %%
df_ROS['입원일자_datetime_day']= df_ROS['입원일자_datetime'].dt.day_name()

# %%
df_ROS['퇴원일자_datetime_day']= df_ROS['퇴원일자_datetime'].dt.day_name()

# %% [markdown]
# ##### 요일별 입원 추이 시각화

# %%
sns.countplot(data=df_ROS, x='입원일자_datetime_day')
plt.show()

# %% [markdown]
# ##### 요일별 퇴원 추이 시각화

# %%
sns.countplot(data=df_ROS, x='퇴원일자_datetime_day')
plt.show()

# %%
sns.histplot(data=df_ROS, x='퇴원일자_datetime_day', kde=True)
plt.show()

# %% [markdown]
# ## quest 2
# - apply() : '신장', '체중' -> BMI
# - BMI 시각화 및 인사이트 분석

# %% [markdown]
# ### 분석결과
# - 현 데이터 환자의 신장과 체중을 통해 BMI수치를 계산하여 BMI분류 분석하였다.
# - 데이터 분석 결과,환자들중  정상체중의 비율이 저체중과 비만에 비해 많음을 확인함
# - 다만,  과체중의 비율이 400명 이상으로 적지는 않음을 확인함
# - 비만에 관한 치료 또는 예방 교육을 현병원에서 실시한다면 수익 또는 병원이용률이 높아짐을 기대할수 있을 것 같음.

# %%
df_ROS[['신장','체중']][:2]
# Out:
#     신장    체중
# 0  163  60.3
# 1  171  71.7

# %%
df_ROS['체중']
# Out:
# 0       60
# 1       71
# 2       77
# 3       74
# 4       80
#         ..
# 1889    64
# 1890    59
# 1891    70
# 1892    77
# 1893    49
# Name: 체중, Length: 1894, dtype: int32

# %%
df_ROS[['신장','체중']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1894 entries, 0 to 1893
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   신장      1894 non-null   int64
#  1   체중      1894 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 29.7 KB

# %%
df_ROS['체중'] = df_ROS['체중'].astype(int)

# %%
df_ROS[['신장','체중']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1894 entries, 0 to 1893
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   신장      1894 non-null   int64
#  1   체중      1894 non-null   int32
# dtypes: int32(1), int64(1)
# memory usage: 22.3 KB

# %%
## bmi 계산식 apply 함수에 적용

def cal_BMI (row):
    weight = row['체중']
    height = row['신장'] / 100  # 키를 cm에서 m로 변환
    bmi = weight/(height * height)
    return bmi

# %%
df_ROS['BMI_수치값']= df_ROS.apply(cal_BMI, axis=1)
df_ROS['BMI_수치값'][:2]
# Out:
# 0    22.582709
# 1    24.280975
# Name: BMI_수치값, dtype: float64

# %%
## bmi 분류 체계 apply()

def classify_obesity(bmi):
    if bmi < 18.5:
        return '저체중'
    elif bmi < 24.9:
        return '정상체중'
    elif bmi < 29.9:
        return '과체중'
    else:
        return '비만'

# %%
df_ROS['BMI_결과분류'] = df_ROS['BMI_수치값'].apply(classify_obesity)
df_ROS['BMI_결과분류'][:2]
# Out:
# 0    정상체중
# 1    정상체중
# Name: BMI_결과분류, dtype: object

# %% [markdown]
# #### bmi 시각화
# - 범주형/연속형

# %%
pd.pivot_table(data=df_ROS[['BMI_결과분류', 'BMI_수치값']], index='BMI_결과분류', aggfunc=len).plot(kind='bar')
# Out:
# <Axes: xlabel='BMI_결과분류'>

# %%
sns.barplot(data=df_ROS, x='BMI_결과분류', y='BMI_수치값', estimator=len )
plt.show()

# %%
sns.lineplot(data=df_ROS, x='BMI_결과분류', y='BMI_수치값', estimator=len)
plt.show()
