# %% [markdown]
# <a href="https://colab.research.google.com/github/GabaeOh/study_data_analytics/blob/main/codes/NLPquest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-mecab-ko pyLDAvis
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 573.9/573.9 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 16.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 29.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 56.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 65.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 29.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import pandas as pd
df = pd.read_csv('./gabaeoh_data_from_hiDoc.csv')
df[:2]
# Out:
#                         _id   question_title  \
# 0  64fece172822f039eb37dab3          강직성 척추염
# 1  64fece172822f039eb37dab4  척추골절 수술 문의드립니다.
#
#                                     question_content question_date  \
# 0  선생님.\n\n강직성 척추염 환자의 90~95%에서 관련 유전자가 검출된다고 하셨는...    2016.03.18
# 1  60대 여성입니다.\n얼마전 허리상해로 mri 를 찍었는데\n병원 주치의 설명으로 ...    2023.05.23
#
#                                       question_tag          answer_title  \
# 0  SMART TAG : 근골격계, 뼈, 정신/신경계, 내과, 류마티스내과, 강직성척추염          Re : 강직성 척추염
# 1         SMART TAG : 근골격계, 뼈, 척추, 정형외과, 재활의학과, 골절  Re : 척추골절 수술 문의드립니다.
#
#   answer_name answer_belong                                     answer_content
# 0   이정찬 [전문의]     서울조인트내과의원  안녕하세요, 하이닥 류마티스내과 상담의 이정찬 입니다.\n\n강직성 척추염의 증상이...
# 1   이이호 [전문의]        진주고려병원      질문자의 감사 인사 | 2023.05.23\n많은 도움이 되었습니다. 고맙습니다.

# %%
list(df['question_content'])

# %%
from gensim.corpora import Dictionary
from gensim.models import LdaModel

# %%
from mecab import MeCab
mecab = MeCab()

# %%
mecab.pos(list(df['question_content']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-d80404638cf5> in <cell line: 1>()
# ----> 1 mecab.pos(list(df['question_content']))
#
# /usr/local/lib/python3.10/dist-packages/mecab/mecab.py in pos(self, sentence)
#      72             A list of `(surface, part-of-speech tag)` pairs representing each morpheme in the given sentence.
#      73         """
# ---> 74         return [(morpheme.surface, morpheme.pos) for morpheme in self.parse(sentence)]
#      75
#      76     def morphs(self, sentence: str) -> list[str]:
#
# /usr/local/lib/python3.10/dist-packages/mecab/mecab.py in parse(self, sentence)
#      57             A list of `Morpheme` objects representing each morpheme in the given sentence.
#      58         """
# ---> 59         lattice = create_lattice(sentence)
#      60         if not self._tagger.parse(lattice):
# ...
